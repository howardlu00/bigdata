# %% [markdown]
# <a href="https://colab.research.google.com/github/howardlu00/bigdata/blob/main/0420%E6%9C%9F%E4%B8%AD%E8%80%83.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
install.packages("ggplot2")
install.packages("SportsAnalytics")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
devtools::install_github('cttobin/ggthemr')
# Out:
# Skipping install of 'ggthemr' from a github remote, the SHA1 (4a31e0df) has not changed since last install.
#   Use `force = TRUE` to force installation

# %%
library(ggthemr)

# %%
ggthemr_reset()

# %%
library(ggplot2)
library(SportsAnalytics)

# %%
NBA1213<-fetch_NBAPlayerStatistics("12-13")

# %%
NBA1213OrderM <- NBA1213[order(NBA1213$GamesPlayed,decreasing = T),]

# %%
NBA1213OrderM[1:20,"Name"]
# Out:
#  [1] "Omer Asik"       "Andray Blatche"  "Corey Brewer"    "Jimmy Butler"
#  [5] "Demar Derozan"   "Monta Ellis"     "Randy Foye"      "Alonzo Gee"
#  [9] "Spencer Hawes"   "Deandre Jordan"  "Damian Lillard"  "Jeremy Lin"
# [13] "Robin Lopez"     "O.j. Mayo"       "Andre Miller"    "Markieff Morris"
# [17] "Lamar Odom"      "Tayshaun Prince" "Luke Ridnour"    "Nate Robinson"

# %%
NBA1213OrderM <- NBA1213[order(NBA1213$GamesStarted,decreasing = T),]

# %%
NBA1213OrderM[1:20,"Team"]
# Out:
#  [1] HOU TOR MIL CLE LAC POR HOU NOR DAL MIN GSW CLE PHI CHA OKL GSW OKL DEN DET
# [20] MEM
# 32 Levels: ATL BOS BRO CHA CHI CLE DAL DEN DET GSW HOU IND LAC LAL MEM ... WAS

# %%
subset(NBA1213,Position="PF")
# Out:
#     League Name             Team Position GamesPlayed TotalMinutesPlayed
# 1   NBA    Quincy Acy       TOR  PF       29           341
# 2   NBA    Jeff Adrien      CHA  SF       52           712
# 3   NBA    Arron Afflalo    ORL  SG       64          2307
# 4   NBA    Josh Akognon     DAL  PG        3             9
# 5   NBA    Cole Aldrich     SAC  C        45           390
# 6   NBA    Lamarcu Aldridge POR  PF       74          2788
# 7   NBA    Lavoy Allen      PHI  PF       79          1668
# 8   NBA    Ray Allen        MIA  SG       79          2033
# 9   NBA    Tony Allen       MEM  PG       79          2112
# 10  NBA    Al-farouq Aminu  NOR  SF       76          2067
# 11  NBA    Lou Amundson     NOR  PF       39           374
# 12  NBA    Chris Andersen   MIA  C        42           626
# 13  NBA    Alan Anderson    TOR  SF       65          1493
# 14  NBA    James Anderson   HOU  SG       39           403
# 15  NBA    Ryan Anderson    NOR  PF       81          2506
# ...

# %%
subset(NBA1213,Team="BRO")
# Out:
#     League Name             Team Position GamesPlayed TotalMinutesPlayed
# 1   NBA    Quincy Acy       TOR  PF       29           341
# 2   NBA    Jeff Adrien      CHA  SF       52           712
# 3   NBA    Arron Afflalo    ORL  SG       64          2307
# 4   NBA    Josh Akognon     DAL  PG        3             9
# 5   NBA    Cole Aldrich     SAC  C        45           390
# 6   NBA    Lamarcu Aldridge POR  PF       74          2788
# 7   NBA    Lavoy Allen      PHI  PF       79          1668
# 8   NBA    Ray Allen        MIA  SG       79          2033
# 9   NBA    Tony Allen       MEM  PG       79          2112
# 10  NBA    Al-farouq Aminu  NOR  SF       76          2067
# 11  NBA    Lou Amundson     NOR  PF       39           374
# 12  NBA    Chris Andersen   MIA  C        42           626
# 13  NBA    Alan Anderson    TOR  SF       65          1493
# 14  NBA    James Anderson   HOU  SG       39           403
# 15  NBA    Ryan Anderson    NOR  PF       81          2506
# ...

# %%
install.packages("data.table")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
library(data.table)

# %%
NBA1213DT <- data.table(NBA1213)

# %%
NBA1213DT[grepl('Curry',Name,)]
# Out:
#   League Name          Team Position GamesPlayed TotalMinutesPlayed
# 1 NBA    Eddie Curry   DAL  C         2            25
# 2 NBA    Stephen Curry GSW  PG       78          2989
#   FieldGoalsMade FieldGoalsAttempted ThreesMade ThreesAttempted ⋯ Steals
# 1   4               8                  0          0             ⋯   0
# 2 626            1388                272        600             ⋯ 127
#   Turnovers Blocks PersonalFouls Disqualifications TotalPoints Technicals
# 1   3        0       7           0                    9        0
# 2 239       12     198           2                 1786        3
#   Ejections FlagrantFouls GamesStarted
# 1 0         0              0
# 2 0         0             78

# %%
NBA1213DT[grepl('Bryant',Name,)]
# Out:
#   League Name        Team Position GamesPlayed TotalMinutesPlayed
# 1 NBA    Kobe Bryant LAL  SG       78          3018
#   FieldGoalsMade FieldGoalsAttempted ThreesMade ThreesAttempted ⋯ Steals
# 1 738            1595                132        407             ⋯ 106
#   Turnovers Blocks PersonalFouls Disqualifications TotalPoints Technicals
# 1 287       25     173           0                 2133        14
#   Ejections FlagrantFouls GamesStarted
# 1 0         0             78

# %%
NBA1213DT[grepl('LAL',Team,)]
# Out:
#    League Name             Team Position GamesPlayed TotalMinutesPlayed
# 1  NBA    Ron Artest       LAL  SF       75          2531
# 2  NBA    Steve Blake      LAL  PG       45          1170
# 3  NBA    Kobe Bryant      LAL  SG       78          3018
# 4  NBA    Earl Clark       LAL  PF       59          1364
# 5  NBA    Chris Duhon      LAL  PG       46           819
# 6  NBA    Devin Ebanks     LAL  SF       19           195
# 7  NBA    Pau Gasol        LAL  PF       49          1655
# 8  NBA    Andrew Goudelock LAL  PG        1             6
# 9  NBA    Jordan Hill      LAL  PF       29           458
# 10 NBA    Dwight Howard    LAL  C        76          2717
# 11 NBA    Antawn Jamison   LAL  PF       76          1638
# 12 NBA    Dar Johnson-odom LAL  PG        4             6
# 13 NBA    Jodie Meeks      LAL  SG       78          1660
# 14 NBA    Darius Morris    LAL  PG       48           688
# 15 NBA    Steve Nash       LAL  PG       50          1631
# ...

# %%
qplot(FieldGoalsAttempted,TotalPoints,data=NBA1213,color=Position)
# Out:
# plot without title

# %%
qplot(FieldGoalsAttempted,TotalPoints,data=NBA1213,color=Position, geom=c("point","smooth"))
# Out:
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
# plot without title

# %%
qplot(FieldGoalsAttempted,TotalPoints,data=NBA1213,color=Position,facets=Position~.)
# Out:
# plot without title

# %%
qplot(FieldGoalsAttempted,TotalPoints,data=NBA1920,color=Position,facets=.~Position)
# Out:
# plot without title

# %%
qplot(ThreesAttempted,TotalPoints,data=NBA1920,color=Position,facets=Position~.)
# Out:
# plot without title

# %%
qplot(ThreesAttempted,TotalPoints,data=NBA1920,color=Position,facets=.~Position)
# Out:
# plot without title

# %%
qplot(TotalPoints,data=NBA1213,fill=Position)
ggthemr("flat")
# Out:
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# plot without title

# %%
qplot(ThreesAttempted,TotalPoints,data=NBA1213,color=Position)
# Out:
# plot without title

# %%
qplot(ThreesAttempted,TotalPoints,data=NBA1213, color=Team)
# Out:
# plot without title

# %%
qplot(FieldGoalsAttempted,TotalPoints,data=NBA1213,color=Team)
# Out:
# plot without title

# %%
qplot(ThreesAttempted,TotalPoints,data=NBA1213,geom=c("point","smooth"),color=Position)
# Out:
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
# plot without title

# %%
qplot(TotalRebounds,data=NBA1213,fill=Position)
# Out:
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# plot without title

# %%
qplot(TotalPoints,data=NBA1213,color=Position,facets=Position~.,binwidth=10)
# Out:
# plot without title

# %%
qplot(TotalPoints,data=NBA1213,fill=Position,facets=Position~.,binwidth=100)
# Out:
# plot without title

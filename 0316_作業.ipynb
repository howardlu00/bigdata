# %% [markdown]
# <a href="https://colab.research.google.com/github/howardlu00/bigdata/blob/main/0316_%E4%BD%9C%E6%A5%AD.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
system("ls", TRUE)
# Out:
# [1] "11003.csv"   "sample_data"

# %%
library(readr)

# %%
dataset <- read.csv("11003.csv")

# %%
dataset
# Out:
#     商號.公司名稱                    統一編號 經營行業
# 1   皇樂舞廳                         10169821 舞廳業
# 2   台南大舞廳                       10806981 舞廳業
# 3   萬象育樂有限公司                 24909208 舞廳業
# 4   夜歡大舞廳                       81554917 舞廳業
# 5   天樂酒家                         71071700 酒家業
# 6   桃源茶室                         73221206 特種咖啡茶室業
# 7   美花園茶室                       71327702 特種咖啡茶室業
# 8   美樂茶室                         74078684 特種咖啡茶室業
# 9   金晶茶坊                               NA 特種咖啡茶室業
# 10  莉芳冷飲店                       47811825 特種咖啡茶室業
# 11  那麼旺茶行                       47788303 特種咖啡茶室業
# 12  綠館三溫暖                       98817392 三溫暖業
# 13  奕植鑽複合式餐廳                 40729934 視聽歌唱業
# 14  美尚美海產                       36824605 視聽歌唱業
# 15  全鴻餐飲店                       62916411 視聽歌唱業
# 16  紅牌視聽歌唱                     14983951 視聽歌唱業
# 17  尚樂小吃店                       36829897 視聽歌唱業
# 18  小上海餐飲                       81407129 視聽歌唱業
# 19  星鑽視聽歌唱                     13207721 視聽歌唱業
# ...

# %%
head(dataset$商號.公司名稱, n=20)
# Out:
#  [1] "皇樂舞廳"         "台南大舞廳"       "萬象育樂有限公司" "夜歡大舞廳"
#  [5] "天樂酒家"         "桃源茶室"         "美花園茶室"       "美樂茶室"
#  [9] "金晶茶坊"         "莉芳冷飲店"       "那麼旺茶行"       "綠館三溫暖"
# [13] "奕植鑽複合式餐廳" "美尚美海產"       "全鴻餐飲店"       "紅牌視聽歌唱"
# [17] "尚樂小吃店"       "小上海餐飲"       "星鑽視聽歌唱"     "小南國餐飲店"

# %%
tail(dataset$商號.公司名稱, n=10)
# Out:
#  [1] "鑫發餐廳"                         "姊妹練歌場"
#  [3] "崴順商行"                         "月娘餐飲店"
#  [5] "無店名"                           "吉宸餐飲店"
#  [7] "美樂地賓士視聽歌唱"               "天上人間視聽歌唱〈羅馬視聽歌唱〉"
#  [9] "白濱冷飲店"                       "好樂迪股份有限公司成功分公司"

# %%
dataset[grepl("白濱冷飲店",dataset$商號.公司名稱),]
# Out:
#     商號.公司名稱 統一編號 經營行業   營業地址
# 252 白濱冷飲店    17212979 視聽歌唱業 臺南市南區竹溪里體育路43巷2號2樓

# %%
dataset[grepl("吉宸餐飲店",dataset$商號.公司名稱),]
# Out:
#     商號.公司名稱 統一編號 經營行業   營業地址
# 249 吉宸餐飲店    85652306 視聽歌唱業 臺南市鹽水區義中里蔡婆1號

# %%
table(dataset$統一編號)
# Out:
#  8954182  9003605  9003611  9042683  9125430  9502905  9522326  9560550
#        1        1        1        1        1        1        1        1
# 10139974 10166015 10168512 10169821 10442217 10450530 10489676 10490580
#        1        1        1        1        1        1        1        1
# 10720605 10726235 10726376 10728064 10739718 10745042 10785352 10806981
#        1        1        1        1        1        1        1        1
# 10812409 10828459 10829794 10836394 10846560 10858777 13206602 13207721
#        1        1        1        1        1        1        1        1
# 13577054 13714748 13719645 13938775 14778038 14983951 15723665 17212979
#        1        1        1        1        1        1        1        1
# 17251661 19711418 19714610 19797724 21652371 21692508 24909208 25774868
#        1        1        1        1        1        1        1        1
# 25777605 26427281 26436556 26439343 26443579 26450584 26455899 26456834
# ...

# %%
table(dataset$商號.公司名稱)
# Out:
#                       一道彩虹餐飲部                       三個八音樂會館
#                                    1                                    1
#                           三合釣蝦場                       上海灘視聽歌唱
#                                    1                                    1
#                           上海灘餐廳                         下營視聽歌唱
#                                    1                                    1
#                            中?小炒店                           中天小吃店
#                                    1                                    1
#                         中天視聽歌唱                           二八九商店
#                                    1                                    1
#                       二十五度冷飲店                       五六九餐飲會館
#                                    1                                    1
#                         五斗米餐飲店                         五星政飲食店
#                                    1                                    1
# ...

# %%
table(dataset$經營行業)
# Out:
#       三溫暖業 特種咖啡茶室業     視聽歌唱業         舞廳業         酒家業
#              1              6            241              4              1

# %%
table(dataset$營業地址)
# Out:
#                                     臺南市下營區新興里中華街202巷132號
#                                                                      1
#          臺南市下營區西連里連表31之8號1樓（營業面積限220．81平方公尺）
#                                                                      1
#                                              臺南市下營區開化里中營1號
#                                                                      1
#                                       臺南市中西區中正里康樂街122號6樓
#                                                                      1
#                                      臺南市中西區中正里康樂街156號12樓
#                                                                      1
#                                     臺南市中西區保安里府前路2段37號1樓
#                                                                      1
#                                     臺南市中西區保安里府前路2段37號2樓
#                                                                      1
#                                     臺南市中西區保安里府前路2段47號1樓
# ...
